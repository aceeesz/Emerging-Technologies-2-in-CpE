# %% [markdown]
# <a href="https://colab.research.google.com/github/aceeesz/Emerging-Technologies-2-in-CpE/blob/main/EFA_HOA3_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Christian Ed B. Efa
# <br>BSCPE32S1
# <br>Emtech 2
# <br>Hands on Activity 3.1 : Data Analysis
# <br>Engr. Ryan Francisco

# %%
import pandas as pd

# %%
brainDF = pd.read_csv('/content/sample_data/brainsize.txt',sep = '\t')

# %%
brainDF
# Out:
#     Gender  FSIQ  VIQ  PIQ  Weight  Height  MRI_Count
# 0   Female   133  132  124   118.0    64.5     816932
# 1     Male   140  150  124     NaN    72.5    1001121
# 2     Male   139  123  150   143.0    73.3    1038437
# 3     Male   133  129  128   172.0    68.8     965353
# 4   Female   137  132  134   147.0    65.0     951545
# 5   Female    99   90  110   146.0    69.0     928799
# 6   Female   138  136  131   138.0    64.5     991305
# 7   Female    92   90   98   175.0    66.0     854258
# 8     Male    89   93   84   134.0    66.3     904858
# 9     Male   133  114  147   172.0    68.8     955466
# 10  Female   132  129  124   118.0    64.5     833868
# 11    Male   141  150  128   151.0    70.0    1079549
# 12    Male   135  129  124   155.0    69.0     924059
# 13  Female   140  120  147   155.0    70.5     856472
# 14  Female    96  100   90   146.0    66.0     878897
# 15  Female    83   71   96   135.0    68.0     865363
# ...

# %%
brainDF.head()
# Out:
#    Gender  FSIQ  VIQ  PIQ  Weight  Height  MRI_Count
# 0  Female   133  132  124   118.0    64.5     816932
# 1    Male   140  150  124     NaN    72.5    1001121
# 2    Male   139  123  150   143.0    73.3    1038437
# 3    Male   133  129  128   172.0    68.8     965353
# 4  Female   137  132  134   147.0    65.0     951545

# %%
brainDF.describe()
# Out:
#              FSIQ         VIQ        PIQ      Weight     Height     MRI_Count
# count   40.000000   40.000000   40.00000   38.000000  39.000000  4.000000e+01
# mean   113.450000  112.350000  111.02500  151.052632  68.525641  9.087550e+05
# std     24.082071   23.616107   22.47105   23.478509   3.994649  7.228205e+04
# min     77.000000   71.000000   72.00000  106.000000  62.000000  7.906190e+05
# 25%     89.750000   90.000000   88.25000  135.250000  66.000000  8.559185e+05
# 50%    116.500000  113.000000  115.00000  146.500000  68.000000  9.053990e+05
# 75%    135.500000  129.750000  128.00000  172.000000  70.500000  9.500780e+05
# max    144.000000  150.000000  150.00000  192.000000  77.000000  1.079549e+06

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
menDf = brainDF[(brainDF.Gender == 'Male')]
womenDf = brainDF[(brainDF.Gender == 'Female')]

# %%
menMeanSmarts = menDf[["PIQ", "FSIQ", "VIQ"]].mean(axis=1)
plt.scatter(menMeanSmarts, menDf["MRI_Count"])
plt.show()
# %matplotlib inline

# %%
# Graph the women-only filtered dataframe
womenMeanSmarts = womenDf[["PIQ", "FSIQ", "VIQ"]].mean(axis=1)
plt.scatter(womenMeanSmarts, womenDf["MRI_Count"])
plt.show()
# %matplotlib inline

# %%
brainDF.corr(method='pearson')
# Out:
# <ipython-input-36-47489f035d3e>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   brainDF.corr(method='pearson')
#                FSIQ       VIQ       PIQ    Weight    Height  MRI_Count
# FSIQ       1.000000  0.946639  0.934125 -0.051483 -0.086002   0.357641
# VIQ        0.946639  1.000000  0.778135 -0.076088 -0.071068   0.337478
# PIQ        0.934125  0.778135  1.000000  0.002512 -0.076723   0.386817
# Weight    -0.051483 -0.076088  0.002512  1.000000  0.699614   0.513378
# Height    -0.086002 -0.071068 -0.076723  0.699614  1.000000   0.601712
# MRI_Count  0.357641  0.337478  0.386817  0.513378  0.601712   1.000000

# %%
womenDf.corr(method='pearson')
# Out:
# <ipython-input-35-01fad84dd5db>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   womenDf.corr(method='pearson')
#                FSIQ       VIQ       PIQ    Weight    Height  MRI_Count
# FSIQ       1.000000  0.955717  0.939382  0.038192 -0.059011   0.325697
# VIQ        0.955717  1.000000  0.802652 -0.021889 -0.146453   0.254933
# PIQ        0.939382  0.802652  1.000000  0.113901 -0.001242   0.396157
# Weight     0.038192 -0.021889  0.113901  1.000000  0.552357   0.446271
# Height    -0.059011 -0.146453 -0.001242  0.552357  1.000000   0.174541
# MRI_Count  0.325697  0.254933  0.396157  0.446271  0.174541   1.000000

# %%
# Use corr() for the male-only dataframe with the pearson method
menDf.corr(method ='pearson')
# Out:
# <ipython-input-41-2b184e44443e>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   menDf.corr(method ='pearson')
#                FSIQ       VIQ       PIQ    Weight    Height  MRI_Count
# FSIQ       1.000000  0.944400  0.930694 -0.278140 -0.356110   0.498369
# VIQ        0.944400  1.000000  0.766021 -0.350453 -0.355588   0.413105
# PIQ        0.930694  0.766021  1.000000 -0.156863 -0.287676   0.568237
# Weight    -0.278140 -0.350453 -0.156863  1.000000  0.406542  -0.076875
# Height    -0.356110 -0.355588 -0.287676  0.406542  1.000000   0.301543
# MRI_Count  0.498369  0.413105  0.568237 -0.076875  0.301543   1.000000

# %%
# !pip install seaborn

# %%
import seaborn as sns
wcorr = womenDf.corr()
sns.heatmap(wcorr)
#plt.savefig('attribute_correlations.png', tight_layout=True)
# Out:
# <ipython-input-46-424452bfc0e4>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   wcorr = womenDf.corr()
# <Axes: >

# %%
mcorr = menDf.corr()
sns.heatmap(mcorr)
#plt.savefig('attribute_correlations.png', tight_layout=True)
# Out:
# <ipython-input-44-77e80db358d6>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mcorr = menDf.corr()
# <Axes: >

# %% [markdown]
# **Many variable pairs present correlation close to zero. What does that mean?**
# <br> - there is no linear relationship exists between two continuous variables
# <br>
#
# **Why separate the genders?**
# <br> - to get the best outcome on each of the male and female
# <br>
#
# **What variables have stronger correlation with brain size (MRI_Count)? Is that expected? Explain.**
# <br> - PIQ, it is expected due to MRI is related to the performance of PIQ

# %%
sampDF = pd.read_csv('/content/comp.txt', sep = '\t')

# %%
sampDF
# Out:
#     Brand     Type  Idle   1C   AC  Unnamed: 5
# 0   Ryzen    5600x    61  111  154         NaN
# 1   Ryzen     7600    89  107  172         NaN
# 2   Ryzen     7700    89  112  177         NaN
# 3   Ryzen     7900   104  126  177         NaN
# 4   Ryzen  5800X3D    59  110  193         NaN
# 5   Ryzen    7600X    88  113  204         NaN
# 6   Ryzen    5950X    60  130  211         NaN
# 7   Intel   12600K    61  103  219         NaN
# 8   Intel   11600K    65  114  221         NaN
# 9   Ryzen    5800X    60  119  221         NaN
# 10  Ryzen    7700X    89  120  222         NaN
# 11  Ryzen    5900X    61  135  222         NaN
# 12  Intel   13600K    67  106  267         NaN
# 13  Intel   11900K    64  122  270         NaN
# 14  Ryzen    7900X   104  136  277         NaN
# 15  Ryzen    7950X   106  135  319         NaN
# 16  Intel   12900K    61  108  334         NaN
# 17  Intel   13900K    67  123  375         NaN

# %%
sampDF.head()
# Out:
#    Brand     Type  Idle   1C   AC  Unnamed: 5
# 0  Ryzen    5600x    61  111  154         NaN
# 1  Ryzen     7600    89  107  172         NaN
# 2  Ryzen     7700    89  112  177         NaN
# 3  Ryzen     7900   104  126  177         NaN
# 4  Ryzen  5800X3D    59  110  193         NaN

# %%
sampDF.describe()
# Out:
#              Idle          1C          AC  Unnamed: 5
# count   18.000000   18.000000   18.000000         0.0
# mean    75.277778  118.333333  235.277778         NaN
# std     17.552629   10.666054   60.397512         NaN
# min     59.000000  103.000000  154.000000         NaN
# 25%     61.000000  110.250000  195.750000         NaN
# 50%     66.000000  116.500000  221.000000         NaN
# 75%     89.000000  125.250000  269.250000         NaN
# max    106.000000  136.000000  375.000000         NaN

# %%
ryzenDf = sampDF[(sampDF.Brand == 'Ryzen')]
intelDf = sampDF[(sampDF.Brand == 'Intel')]

# %%
ryMeanSmarts = ryzenDf[["Idle", "1C"]].mean(axis=1)
plt.scatter(ryMeanSmarts, ryzenDf["AC"])
plt.show()
# %matplotlib inline

# %%
inMeanSmarts = intelDf[["Idle", "1C"]].mean(axis=1)
plt.scatter(inMeanSmarts, intelDf["AC"])
plt.show()
# %matplotlib inline

# %%
ryzenDf.corr(method='pearson')
# Out:
# <ipython-input-75-56fdd0db6deb>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   ryzenDf.corr(method='pearson')
#                 Idle        1C        AC  Unnamed: 5
# Idle        1.000000  0.251388  0.405484         NaN
# 1C          0.251388  1.000000  0.745237         NaN
# AC          0.405484  0.745237  1.000000         NaN
# Unnamed: 5       NaN       NaN       NaN         NaN

# %%
intelDf.corr(method='pearson')
# Out:
# <ipython-input-76-fc378c1c858b>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   intelDf.corr(method='pearson')
#                 Idle        1C        AC  Unnamed: 5
# Idle        1.000000  0.483669  0.244840         NaN
# 1C          0.483669  1.000000  0.469926         NaN
# AC          0.244840  0.469926  1.000000         NaN
# Unnamed: 5       NaN       NaN       NaN         NaN

# %%
import seaborn as sns
rcorr = ryzenDf.corr()
sns.heatmap(rcorr)
#plt.savefig('attribute_correlations.png', tight_layout=True)
# Out:
# <ipython-input-78-c1bc0f624b80>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   rcorr = ryzenDf.corr()
# <Axes: >

# %%
import seaborn as sns
icorr = intelDf.corr()
sns.heatmap(icorr)
#plt.savefig('attribute_correlations.png', tight_layout=True)
# Out:
# <ipython-input-79-02d2360e00ce>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   icorr = intelDf.corr()
# <Axes: >
